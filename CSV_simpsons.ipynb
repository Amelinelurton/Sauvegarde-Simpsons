# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re




persocharacters = pd.read_csv("/Users/macameline/Documents/learn_code/THP_DATA/Projet_finale/Sources_Simpsons/simpsons_characters_categ.csv", sep=",")
persocharacters
# Out:
#       Unnamed: 0                                    0  \
# 0            706  Characters from different countries
# 1            708  Characters from different countries
# 2            710  Characters from different countries
# 3            711  Characters from different countries
# 4            713  Characters from different countries
# ...          ...                                  ...
# 3036        6750                  American Characters
# 3037        6751                  American Characters
# 3038        6752                  American Characters
# 3039        6753                  American Characters
# 3040        6754                  American Characters
#
#                                       1
# 0     Adolf Hitler (Bart vs. Australia)
# 1                                    Ak
# 2                      Kumiko Albertson
# 3                          Alex Salmond
# 4                                  Anya
# ...                                 ...
# ...

# %%
persocharacters = persocharacters.rename(columns={"0": "Characters", "1": "Perso"})
persocharacters
# Out:
#       Unnamed: 0                           Characters  \
# 0            706  Characters from different countries
# 1            708  Characters from different countries
# 2            710  Characters from different countries
# 3            711  Characters from different countries
# 4            713  Characters from different countries
# ...          ...                                  ...
# 3036        6750                  American Characters
# 3037        6751                  American Characters
# 3038        6752                  American Characters
# 3039        6753                  American Characters
# 3040        6754                  American Characters
#
#                                   Perso
# 0     Adolf Hitler (Bart vs. Australia)
# 1                                    Ak
# 2                      Kumiko Albertson
# 3                          Alex Salmond
# 4                                  Anya
# ...                                 ...
# ...

# %% [markdown]
# # Répartition selon les caratéristiques des personnages

# %%
nbr_characters=persocharacters.Characters.value_counts()
nbr_characters
# Out:
# Adults                                    200
# Recurring characters                      200
# Self-voicing guest stars                  200
# American Characters                       199
# Male characters                           199
# Seniors                                   199
# Female characters                         198
# Real world characters                     197
# Citizens of Springfield                   196
# Children                                  193
# African-American Characters               189
# Springfield Elementary School students    185
# Characters from different countries       118
# Teenagers                                 100
# Rich Characters                            99
# Babies                                     72
# Families                                   62
# Retired Characters                         58
# Major Characters                           49
# Main Characters                            43
# ...

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.hlines(nbr_characters.index, xmin=0, xmax=nbr_characters.values, linewidth=2,color= '#307DBA')
ax.plot(nbr_characters.values, nbr_characters.index, 's', markersize=10,color='#F5C024', alpha=0.5)
ax.invert_yaxis()

ax.set_title('Particularités des personnages')
ax.set_xlabel('Nombre')


plt.show()

# %%
persorank = pd.read_csv("/Users/macameline/Documents/learn_code/THP_DATA/Projet_finale/Sources_Simpsons/simpsons_characters_ranked.csv", sep=",")
persorank
# Out:
#     rank                  character
# 0     50             Lindsey Naegle
# 1     49           Sherri and Terri
# 2     48                Mrs. Hoover
# 3     47            Cletus Spuckler
# 4     46                  Otto Mann
# 5     45      Rod and Todd Flanders
# 6     44             Kang and Kodos
# 7     43                   Fat Tony
# 8     42    Superintendent Chalmers
# 9     41               Frank Grimes
# 10    40       Bleeding Gums Murphy
# 11    39              Agnes Skinner
# 12    38               Mayor Quimby
# 13    37              Kent Brockman
# 14    36              Gil Gunderson
# 15    35           Dr. Nick Riviera
# 16    34             Comic Book Guy
# 17    33               Sideshow Mel
# 18    32               Nelson Muntz
# 19    31              Helen Lovejoy
# 20    30           Luann Van Houten
# 21    29               Carl Carlson
# 22    28              Lenny Leonard
# 23    27                Dr. Hibbert
# 24    26               Chief Wiggum
# ...

# %%
persorank = persorank.rename(columns={"character": "perso"})

# %% [markdown]
# # Classsement des personnages

# %%
rank = persorank.sort_values('rank')
rank
# Out:
#     rank                      perso
# 49     1              Marge Simpson
# 48     2              Homer Simpson
# 47     3               Lisa Simpson
# 46     4               Ned Flanders
# 45     5        Milhouse Van Houten
# 44     6            Seymour Skinner
# 43     7               Bart Simpson
# 42     8                Moe Syszlak
# 41     9     Apu Nahasapeemapetilon
# 40    10           Krusty the Clown
# 39    11   Charles Montgomery Burns
# 38    12               Sideshow Bob
# 37    13            Abraham Simpson
# 36    14             Edna Krabappel
# 35    15               Ralph Wiggum
# 34    16            Waylon Smithers
# 33    17             Maggie Simpson
# 32    18                Lionel Hutz
# 31    19           Reverend Lovejoy
# 30    20               Troy McClure
# 29    21       Groundskeeper Willie
# 28    22              Barney Gumble
# 27    23              Martin Prince
# 26    24              Selma Bouvier
# 25    25              Patty Bouvier
# ...

# %%
persogender = pd.read_csv("/Users/macameline/Documents/learn_code/THP_DATA/Projet_finale/Sources_Simpsons/simpsons_characters.csv", sep=",")
persogender
# Out:
#         id              name   normalized_name gender
# 0        7          Children          children    NaN
# 1       12  Mechanical Santa  mechanical santa    NaN
# 2       13        Tattoo Man        tattoo man    NaN
# 3       16  DOCTOR ZITSOFSKY  doctor zitsofsky    NaN
# 4       20          Students          students    NaN
# ...    ...               ...               ...    ...
# 6717  5222    Ron Rabinowitz    ron rabinowitz      m
# 6718  5728    Martha Stewart    martha stewart      f
# 6719  1770   Officer Goodman   officer goodman      m
# 6720  1634      Evan Conover      evan conover      m
# 6721  1868     Agent Johnson     agent johnson      m
#
# [6722 rows x 4 columns]

# %%
persogender = persogender.replace('m', 'masculin', regex=True)
persogender = persogender.replace('f', 'féminin', regex=True)
persogender
# Out:
#         id                                name  \
# 0        7                            Children
# 1       12                    Mechanical Santa
# 2       13                          Tattoo Man
# 3       16                    DOCTOR ZITSOFSKY
# 4       20                            Students
# ...    ...                                 ...
# 6717  5222                      Ron Rabinowitz
# 6718  5728                      Martha Stewart
# 6719  1770  Ofémininfémininicer Goodmasculinan
# 6720  1634                        Evan Conover
# 6721  1868                       Agent Johnson
#
#                          normalized_name    gender
# 0                               children       NaN
# 1                masculinechanical santa       NaN
# 2                      tattoo masculinan       NaN
# 3                 doctor zitsofémininsky       NaN
# 4                               students       NaN
# ...                                  ...       ...
# ...

# %% [markdown]
# # Repartition selon le sexe

# %%
nbr_gender=persogender.gender.value_counts()

nbr_gender
# Out:
# masculin    252
# féminin      71
# Name: gender, dtype: int64

# %%
data4 = pd.read_csv("/Users/macameline/Documents/learn_code/THP_DATA/Projet_finale/Sources_Simpsons/simpsons_episodes.csv", sep=",")
data4
# Out:
#       id                                          image_url  imdb_rating  \
# 0     10  http://static-media.fxx.com/img/FX_Networks_-_...          7.4
# 1     12  http://static-media.fxx.com/img/FX_Networks_-_...          8.3
# 2     14  http://static-media.fxx.com/img/FX_Networks_-_...          8.2
# 3     17  http://static-media.fxx.com/img/FX_Networks_-_...          8.1
# 4     19  http://static-media.fxx.com/img/FX_Networks_-_...          8.0
# ..   ...                                                ...          ...
# 595  500  http://static-media.fxx.com/img/FX_Networks_-_...          7.0
# 596  502  http://static-media.fxx.com/img/FX_Networks_-_...          7.3
# 597  511  http://static-media.fxx.com/img/FX_Networks_-_...          6.9
# 598  542  http://static-media.fxx.com/img/FX_Networks_-_...          6.4
# 599  548  http://static-media.fxx.com/img/FX_Networks_-_...          7.0
#
#      imdb_votes  number_in_season  number_in_series original_air_date  \
# ...

# %% [markdown]
# # Classement episode

# %%
data4.imdb_rating.sort_values(ascending = False)
# Out:
# 537    9.2
# 535    9.2
# 323    9.1
# 534    9.1
# 261    9.0
#       ...
# 71     5.1
# 193    4.5
# 234    NaN
# 235    NaN
# 236    NaN
# Name: imdb_rating, Length: 600, dtype: float64

# %%
data5 = pd.read_csv("/Users/macameline/Documents/learn_code/THP_DATA/Projet_finale/Sources_Simpsons/simpsons_imdb.csv", sep=",")
data5
# Out:
#      Unnamed: 0                              title  \
# 0             0  Simpsons Roasting on an Open Fire
# 1             1                    Bart the Genius
# 2             2                    Homer's Odyssey
# 3             3      There's No Disgrace Like Home
# 4             4                   Bart the General
# ..          ...                                ...
# 722         722           My Octopus and a Teacher
# 723         723         Girls Just Shauna Have Fun
# 724         724                   Marge the Meanie
# 725         725                     Meat Is Murder
# 726         726                     Poorhouse Rock
#
#                                              summaries  \
# 0    Homer is forced to become a department store S...
# 1    Bart ends up at a school for gifted children a...
# 2    After losing his job, Homer contemplates endin...
# 3    After being embarrassed by the rest of the fam...
# 4    After being beaten up by Nelson Muntz one too ...
# ...

# %%
location = pd.read_csv("/Users/macameline/Documents/learn_code/THP_DATA/Projet_finale/Sources_Simpsons/simpsons_locations_categ.csv", sep=",")
location
# Out:
#       Unnamed: 0  categ_location                  location
# 0              0  Accommodations        1 Ocean View Drive
# 1              1  Accommodations  15201 Maple Systems Road
# 2              2  Accommodations       19 Fish Smell Drive
# 3              3  Accommodations              257th Street
# 4              4  Accommodations         316 Pikeland Ave.
# ...          ...             ...                       ...
# 1682        1749         Beaches           Dimoxinil Beach
# 1683        1750         Beaches               Miami Beach
# 1684        1751         Beaches               Sandy Beach
# 1685        1752         Beaches         Shelbyville Beach
# 1686        1753         Beaches         Springfield Beach
#
# [1687 rows x 3 columns]

# %% [markdown]
# # Repartition par lieu

# %%
nbr_lieu = location.categ_location.value_counts()
nbr_lieu.head(30)
# Out:
# American Locations                          200
# Businesses                                  190
# Countries                                   153
# Companies                                   147
# Accommodations                              134
# Location stubs                              113
# Homes                                       108
# Towns and cities                            104
# Springfield Mall                             89
# Schools and other educational facilities     57
# Medical and Health Facilities                55
# Natural Landmarks                            54
# Springfield Elementary School                44
# Houses with unknown addresses                37
# Parks and recreational areas                 29
# Museums                                      26
# Streets in Springfield                       23
# Stadiums                                     21
# Prisons                                      16
# Arcades and fun centers                      16
# ...

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.hlines(nbr_lieu.index, xmin=0, xmax=nbr_lieu.values, linewidth=2)
ax.plot(nbr_lieu.values, nbr_lieu.index, 's', markersize=10, alpha=0.5)
ax.invert_yaxis()

ax.set_title('Les types de lieu les plus présent dans la serie')
ax.set_xlabel('Nombre de lieu')

plt.show()

# %%
data7 = pd.read_csv("/Users/macameline/Documents/learn_code/THP_DATA/Projet_finale/Sources_Simpsons/simpsons_locations.csv", sep=",")
data7
# Out:
#         id                           name                normalized_name
# 0        1                         Street                         street
# 1        2                            Car                            car
# 2        3  Springfield Elementary School  springfield elementary school
# 3        4                     Auditorium                     auditorium
# 4        5                   Simpson Home                   simpson home
# ...    ...                            ...                            ...
# 4454  4455                        SKOBO'S                          skobo
# 4455  4456             FLANDERS' BASEMENT              flanders basement
# 4456  4457                   CASINO FLOOR                   casino floor
# 4457  4458                  BURNED CHURCH                  burned church
# 4458  4459               PLAYDUDE MANSION               playdude mansion
#
# [4459 rows x 3 columns]

# %%
spoken = pd.read_csv("/Users/macameline/Documents/learn_code/THP_DATA/Projet_finale/Sources_Simpsons/simpsons_script_lines.csv", sep=",")
spoken
# Out:
# /var/folders/vy/ftxg8znx7jvfb6xqccmz028c0000gn/T/ipykernel_32357/411459967.py:1: DtypeWarning: Columns (4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   spoken = pd.read_csv("/Users/macameline/Documents/learn_code/THP_DATA/Projet_finale/Sources_Simpsons/simpsons_script_lines.csv", sep=",")
#           id  episode_id  number  \
# 0       9549          32     209
# 1       9550          32     210
# 2       9551          32     211
# 3       9552          32     212
# 4       9553          32     213
# ...      ...         ...     ...
# 158266  9544          32     204
# 158267  9545          32     205
# 158268  9546          32     206
# 158269  9547          32     207
# 158270  9548          32     208
#
#                                                  raw_text timestamp_in_ms  \
# 0       Miss Hoover: No, actually, it was a little of ...          848000
# 1       Lisa Simpson: (NEAR TEARS) Where's Mr. Bergstrom?          856000
# ...

# %% [markdown]
# # dialogue par épisode

# %%
episode = spoken.episode_id.value_counts()
episode
# Out:
# 228    395
# 1      377
# 231    376
# 271    375
# 28     367
#       ...
# 138    208
# 568    206
# 554    204
# 286    146
# 189     79
# Name: episode_id, Length: 564, dtype: int64

# %% [markdown]
# # Personnages

# %%
personnage = spoken.raw_character_text.value_counts()
'''personnage.columns.names = ['Prise de parole']
personnage.index.names =['Personnage']'''

personnage.head(20)
# Out:
# Homer Simpson              29842
# Marge Simpson              14159
# Bart Simpson               13777
# Lisa Simpson               11502
# C. Montgomery Burns         3172
# Moe Szyslak                 2864
# Seymour Skinner             2443
# Ned Flanders                2145
# Grampa Simpson              1886
# Milhouse Van Houten         1862
# Chief Wiggum                1836
# Krusty the Clown            1772
# Nelson Muntz                1174
# Lenny Leonard               1166
# Apu Nahasapeemapetilon      1006
# Waylon Smithers             1001
# Kent Brockman                894
# Carl Carlson                 883
# Edna Krabappel-Flanders      745
# Dr. Julius Hibbert           693
# Name: raw_character_text, dtype: int64

# %%
df_personnage = pd.DataFrame({'Nb': personnage}) 
df_personnage['Persos'] = df_personnage.index 
df_personnage
# Out:
#                                    Nb                          Persos
# Homer Simpson                   29842                   Homer Simpson
# Marge Simpson                   14159                   Marge Simpson
# Bart Simpson                    13777                    Bart Simpson
# Lisa Simpson                    11502                    Lisa Simpson
# C. Montgomery Burns              3172             C. Montgomery Burns
# ...                               ...                             ...
# Disgruntled Audience Member #3      1  Disgruntled Audience Member #3
# Chinese Acrobats                    1                Chinese Acrobats
# Kindergarten Kids                   1               Kindergarten Kids
# Muscular Homer                      1                  Muscular Homer
# Network Announcer                   1               Network Announcer
#
# [6765 rows x 2 columns]

# %%
top_15spoken = df_personnage[:15]
top_15spoken
# Out:
#                            Nb                  Persos
# Homer Simpson           29842           Homer Simpson
# Marge Simpson           14159           Marge Simpson
# Bart Simpson            13777            Bart Simpson
# Lisa Simpson            11502            Lisa Simpson
# C. Montgomery Burns      3172     C. Montgomery Burns
# Moe Szyslak              2864             Moe Szyslak
# Seymour Skinner          2443         Seymour Skinner
# Ned Flanders             2145            Ned Flanders
# Grampa Simpson           1886          Grampa Simpson
# Milhouse Van Houten      1862     Milhouse Van Houten
# Chief Wiggum             1836            Chief Wiggum
# Krusty the Clown         1772        Krusty the Clown
# Nelson Muntz             1174            Nelson Muntz
# Lenny Leonard            1166           Lenny Leonard
# Apu Nahasapeemapetilon   1006  Apu Nahasapeemapetilon

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.hlines(top_15spoken.index, xmin=0, xmax=top_15spoken.Nb, linewidth=2)
ax.plot(top_15spoken.Nb, top_15spoken.index, 'o', markersize=10, alpha=0.5)
ax.invert_yaxis()

ax.set_title('Top 15 des prises de parole selon les personnages')
ax.set_xlabel('Prise de paroles')


plt.show()

# %% [markdown]
# # location

# %%
location = spoken.raw_location_text.value_counts()
location
# Out:
# Simpson Home                       35059
# Springfield Elementary School       7092
# Moe's Tavern                        4628
# Springfield Nuclear Power Plant     3594
# Kwik-E-Mart                         1476
#                                    ...
# RED LIGHT DISTRICT                     1
# ROLLER COASTER                         1
# Toys Я Us                              1
# DOWNTOWN KNOXVILLE STREET              1
# DUMP                                   1
# Name: raw_location_text, Length: 4498, dtype: int64

# %%
top_15location = location[:15]
top_15location
# Out:
# Simpson Home                       35059
# Springfield Elementary School       7092
# Moe's Tavern                        4628
# Springfield Nuclear Power Plant     3594
# Kwik-E-Mart                         1476
# First Church of Springfield         1416
# Simpson Living Room                 1378
# Springfield Street                  1334
# Springfield                         1314
# Simpson Car                         1239
# Flanders Home                       1166
# Street                              1124
# Springfield Town Hall               1103
# Springfield Retirement Castle       1049
# Burns Manor                          998
# Name: raw_location_text, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.hlines(top_15location.index, xmin=0, xmax=top_15location.values, linewidth=2)
ax.plot(top_15location.values, top_15location.index, 'o', markersize=10, alpha=0.5)
ax.invert_yaxis()

ax.set_title('Localisation des prises de parole top 15')
ax.set_xlabel('Prise de paroles')


plt.show()

# %% [markdown]
# # Répétition dialogue

# %%
repe = spoken.spoken_words.value_counts()
repe.head(40)
# Out:
# No.                  305
# What?                142
# Okay.                138
# Yes.                 130
# Huh?                 128
# Woo hoo!             124
# Yeah.                120
# Homer!               108
# No!                  104
# Uh-oh.               104
# Ow!                   92
# Hey!                  80
# Oh.                   74
# Sorry.                72
# Bart!                 69
# Yay!                  67
# Thank you.            66
# Yes!                  65
# Really?               59
# Haw haw!              55
# Uh-huh.               49
# Why you little...     47
# Yeah!                 47
# Fine.                 46
# All right.            46
# Excellent.            44
# Dad!                  41
# What?!                40
# Yes, sir.             37
# Sure.                 34
# Shut up!              34
# Hello?                32
# Oh my God!            31
# Nooo!                 31
# Dammit!               30
# Hello.                30
# What the?             29
# ...

# %%
repen = spoken.normalized_text.value_counts()
repen.head(40)
# Out:
# no                426
# yes               238
# what              192
# yeah              187
# homer             173
# okay              155
# huh               134
# woo hoo           125
# ow                119
# uh-oh             113
# oh                108
# hey               101
# bart               93
# thank you          86
# haw haw            85
# dad                78
# sorry              77
# oh yeah            77
# hello              75
# why you little     73
# yay                71
# all right          70
# really             63
# shut up            63
# yes sir            61
# uh-huh             61
# what the           59
# wow                56
# oh my god          54
# marge              53
# awww               51
# excellent          49
# fine               48
# oh no              45
# sure               44
# cool               44
# lisa               43
# whoa               42
# ay carumba         40
# hmmm               37
# Name: normalized_text, dtype: int64

# %% [markdown]
# # Moyenne des répétition

# %%
repen.mean()
# Out:
# 1.102525792127141

# %% [markdown]
# # Moyenne de mots par prise de parole des personnage

# %%
meanword = spoken.mean()
meanword
# Out:
# /var/folders/vy/ftxg8znx7jvfb6xqccmz028c0000gn/T/ipykernel_32357/2743287552.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   meanword = spoken.mean()
# id             79163.141037
# episode_id       278.452306
# number           141.527216
# location_id      846.277942
# dtype: float64

# %% [markdown]
# # Dialogue personnage

# %%
spoken
# Out:
#           id  episode_id  number  \
# 0       9549          32     209
# 1       9550          32     210
# 2       9551          32     211
# 3       9552          32     212
# 4       9553          32     213
# ...      ...         ...     ...
# 158266  9544          32     204
# 158267  9545          32     205
# 158268  9546          32     206
# 158269  9547          32     207
# 158270  9548          32     208
#
#                                                  raw_text timestamp_in_ms  \
# 0       Miss Hoover: No, actually, it was a little of ...          848000
# 1       Lisa Simpson: (NEAR TEARS) Where's Mr. Bergstrom?          856000
# 2       Miss Hoover: I don't know. Although I'd sure l...          856000
# 3                Lisa Simpson: That life is worth living.          864000
# 4       Edna Krabappel-Flanders: The polls will be ope...          864000
# ...                                                   ...             ...
# ...

# %% [markdown]
# # Analyse dialogue Personnages

# %% [markdown]
# # id personnage
#     character_id= 2: homer
#     character_id= 8: bart
#     character_id= 1: marge
#     character_id= 9: lisa

# %% [markdown]
# # Homer

# %%
homer = spoken[spoken['character_id'] == 2]
homer
# Out:
#             id  episode_id  number  \
# 57        9660          33       5
# 58        9605          32     265
# 62        9609          32     269
# 64        9611          32     271
# 66        9613          32     273
# ...        ...         ...     ...
# 131064  141366         505      49
# 131065  141367         505      50
# 131066  141368         505      51
# 131068  141370         505      53
# 131070  141372         505      55
#
#                                                  raw_text timestamp_in_ms  \
# 57      Homer Simpson: (INDIGNANT) Never thrown a part...           97000
# 58      Homer Simpson: (MULLING IT OVER, LOW, TO HIMSE...         1070000
# 62                                     Homer Simpson: Oh.         1086000
# 64                                    Homer Simpson: And?         1088000
# 66      Homer Simpson: Hey, just because I don't care ...         1091000
# ...                                                   ...             ...
# ...

# %%
location_homer= homer.raw_location_text.value_counts()
location_homer.head(10)
# Out:
# Simpson Home                       8188
# Moe's Tavern                        844
# Springfield Nuclear Power Plant     771
# Simpson Car                         326
# Kwik-E-Mart                         249
# Simpson Living Room                 246
# Springfield Street                  197
# Homer's Car                         187
# Street                              186
# Simpson Kitchen                     176
# Name: raw_location_text, dtype: int64

# %%
spoke_homer= homer.normalized_text.value_counts()
spoke_homer.head(10)
# Out:
# woo hoo           96
# no                74
# okay              53
# why you little    50
# huh               45
# yes               36
# yeah              35
# uh-oh             34
# what              31
# marge             31
# Name: normalized_text, dtype: int64

# %%
spoken_homer= homer.spoken_words.value_counts()
spoken_homer.head(10)
# Out:
# Woo hoo!             96
# No.                  51
# Huh?                 45
# Okay.                45
# Why you little...    35
# Uh-oh.               34
# Sorry.               24
# What?                24
# Yeah.                22
# Oh.                  20
# Name: spoken_words, dtype: int64

# %%
print(homer.word_count.describe())
# Out:
# count     23075
# unique       80
# top           4
# freq       1762
# Name: word_count, dtype: object

# %%
#homer.word_count.mean()

# %%
episode_spoke_homer=homer.episode_id.value_counts()
episode_spoke_homer
# Out:
# 231    145
# 351    122
# 293    119
# 222    117
# 254    117
#       ...
# 100      7
# 150      7
# 392      7
# 506      2
# 324      1
# Name: episode_id, Length: 472, dtype: int64

# %% [markdown]
# # bart

# %%
bart = spoken[spoken['character_id'] == 8]
bart
# Out:
#             id  episode_id  number  \
# 7         9556          32     216
# 17        9566          32     226
# 19        9568          32     228
# 21        9570          32     230
# 23        9572          32     232
# ...        ...         ...     ...
# 131051  141354         505      37
# 131052  141355         505      38
# 131056  141359         505      42
# 131062  141365         505      48
# 131071  141373         505      56
#
#                                                  raw_text timestamp_in_ms  \
# 7            Bart Simpson: Victory party under the slide!          882000
# 17          Bart Simpson: Hey, thanks for your vote, man.          918000
# 19      Bart Simpson: Well, you got that right. (TO TE...          922000
# 21      Bart Simpson: Well, don't sweat it. Just so lo...          927000
# 23                                   Bart Simpson: Lewis?          931000
# ...                                                   ...             ...
# ...

# %%
location_bart= bart.raw_location_text.value_counts()
location_bart.head(10)
# Out:
# Simpson Home                                  3449
# Springfield Elementary School                  741
# Bart's Bedroom                                 172
# Bart's Treehouse                               166
# Springfield Street                             136
# Simpson Car                                    113
# Simpson Living Room                             94
# The Android's Dungeon & Baseball Card Shop      92
# Lisa's Bedroom                                  87
# Springfield Mall                                86
# Name: raw_location_text, dtype: int64

# %%
spoke_bart= bart.normalized_text.value_counts()
spoke_bart.head(10)
# Out:
# no            43
# cool          30
# ow            27
# huh           27
# yeah          27
# uh-oh         26
# dad           25
# what          19
# ay carumba    19
# yes           17
# Name: normalized_text, dtype: int64

# %%
spoken_bart= bart.spoken_words.value_counts()
spoken_bart.head(10)
# Out:
# No.            34
# Uh-oh.         25
# Huh?           25
# Ow!            22
# Yeah.          18
# Okay.          15
# What?          14
# Cool!          14
# Cool.          13
# Ay carumba!    13
# Name: spoken_words, dtype: int64

# %%
episode_spoke_bart=bart.episode_id.value_counts()
episode_spoke_bart
# Out:
# 34     122
# 243    103
# 196     93
# 449     92
# 173     90
#       ...
# 147      2
# 404      2
# 232      1
# 409      1
# 436      1
# Name: episode_id, Length: 470, dtype: int64

# %% [markdown]
# # lisa

# %%
lisa = spoken[spoken['character_id'] == 9]
lisa
# Out:
#             id  episode_id  number  \
# 1         9550          32     210
# 3         9552          32     212
# 9         9558          32     218
# 11        9560          32     220
# 13        9562          32     222
# ...        ...         ...     ...
# 130989  141293         504     247
# 130995  141299         504     253
# 131038  141341         505      24
# 131054  141357         505      40
# 131058  141361         505      44
#
#                                                  raw_text timestamp_in_ms  \
# 1       Lisa Simpson: (NEAR TEARS) Where's Mr. Bergstrom?          856000
# 3                Lisa Simpson: That life is worth living.          864000
# 9       Lisa Simpson: (CALLING) Mr. Bergstrom! Mr. Ber...          889000
# 11      Lisa Simpson: Do you know where I could find him?          898000
# 13      Lisa Simpson: The train, how like him... tradi...          903000
# ...                                                   ...             ...
# ...

# %%
location_lisa= lisa.raw_location_text.value_counts()
location_lisa.head(10)
# Out:
# Simpson Home                     3298
# Springfield Elementary School     516
# Lisa's Bedroom                    183
# Simpson Car                       113
# Simpson Living Room               108
# Simpson Kitchen                    91
# Bart's Bedroom                     74
# Springfield Town Hall              72
# Street                             68
# Springfield Street                 66
# Name: raw_location_text, dtype: int64

# %%
spoke_lisa= lisa.normalized_text.value_counts()
spoke_lisa.head(10)
# Out:
# no      45
# dad     28
# yes     26
# bart    20
# what    17
# yay     16
# hey     15
# mom     14
# okay    13
# yeah    12
# Name: normalized_text, dtype: int64

# %%
spoken_lisa= lisa.spoken_words.value_counts()
spoken_lisa.head(10)
# Out:
# No.      30
# Yay!     16
# Dad!     15
# Yes.     15
# Bart!    14
# Okay.    12
# No!      12
# What?    11
# Hey!     11
# Huh?     11
# Name: spoken_words, dtype: int64

# %%
episode_spoke_lisa=lisa.episode_id.value_counts()
episode_spoke_lisa
# Out:
# 170    86
# 204    77
# 202    75
# 122    72
# 219    69
#        ..
# 261     2
# 486     2
# 141     1
# 475     1
# 446     1
# Name: episode_id, Length: 469, dtype: int64

# %% [markdown]
# # marge

# %%
marge = spoken[spoken['character_id'] == 1]
marge
# Out:
#             id  episode_id  number  \
# 60        9607          32     267
# 74        9621          32     281
# 84        9661          33       6
# 86        9663          33       8
# 109       9653          32     313
# ...        ...         ...     ...
# 131048  141351         505      34
# 131053  141356         505      39
# 131055  141358         505      41
# 131057  141360         505      43
# 131060  141363         505      46
#
#                                                  raw_text timestamp_in_ms  \
# 60                 Marge Simpson: Lisa, tell your father.         1082000
# 74      Marge Simpson: Homer, you are not allowed to h...         1129000
# 84                   Marge Simpson: That was our wedding.          103000
# 86      Marge Simpson: (LOOKS UP) Children, it's time ...          105000
# 109     Marge Simpson: Homie, did you straighten every...         1292000
# ...                                                   ...             ...
# ...

# %%
location_marge= marge.raw_location_text.value_counts()
location_marge.head(10)
# Out:
# Simpson Home                     5149
# Simpson Car                       166
# Simpson Kitchen                   152
# Simpson Living Room               142
# First Church of Springfield       116
# Moe's Tavern                      103
# Springfield Elementary School      91
# Kwik-E-Mart                        70
# Springfield Street                 70
# Simpson Master Bedroom             63
# Name: raw_location_text, dtype: int64

# %%
spoke_marge= marge.normalized_text.value_counts()
spoke_marge.head(10)
# Out:
# homer       91
# no          59
# bart        28
# what        21
# yes         18
# oh          17
# homie       15
# hello       15
# oh homie    14
# lisa        13
# Name: normalized_text, dtype: int64

# %%
spoken_marge= marge.spoken_words.value_counts()
spoken_marge.head(10)
# Out:
# Homer!    62
# No.       35
# No!       22
# Bart!     20
# Hello?    13
# Yes.      12
# Homer?    12
# What?     11
# Oh.       10
# What?!    10
# Name: spoken_words, dtype: int64

# %%
episode_spoke_marge=marge.episode_id.value_counts()
episode_spoke_marge
# Out:
# 376    80
# 126    79
# 300    77
# 187    76
# 106    74
#        ..
# 108     3
# 475     3
# 32      3
# 130     2
# 443     1
# Name: episode_id, Length: 470, dtype: int64
